# %% [markdown]
# # Annotation pipeline status

# %% [markdown]
#  - Have run both check_ol and check_nr to select best gene models, remove overlapping genes and check for protein redundancies.
#  - Have run blastn on RepeatMasking library.
#  - Completed genemark training using the chromosome 1 gff with best gene models and no overlap.

# %% [markdown]
# # Subsequent steps
#
#  - Check whether % identity of protein redundancy exceeds 70%. They should not do. The file that contains such information is pc_out.sorted. If any exceeds it, delete genemark training.
#  - Need to check with Rob if the "LTR" elements need to be removed from RepeatMasking library?
#  - Check with Rob on whether augustus should also be trained?
#  - Download curated / "reviewed" protein sequences of fusarium from Uniprot.
#  - 2 maker runs.

# %% [markdown]
# # Input for next steps
#
#  - See files flowchart
#
#  - Train genemark using best_gene_mdoels/makerRNAs.filtered.nolaps.gff contains best gene models with the overlaps being deleted.
#
#  - Do not use maker.RNAs.filtered.gff as done with Aphid because this still contains overlaps.

# %% [markdown]
# # Tricks learnt:
#  - tee command linux works akin to tee junction that prints output both to a designated file and to the display.

# %% [markdown]
# ![image.png](attachment:image.png)
