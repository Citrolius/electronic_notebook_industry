# %%
import requests, sys
 
server = "https://rest.ensembl.org"
ext = "/info/species?"
 
r = requests.get(server+ext, headers={ "Content-Type" : "application/json"})
 
if not r.ok:
  r.raise_for_status()
  sys.exit()
 
decoded = r.json()
#print(repr(decoded))
#print(type(r))
#print(type(decoded))
#print(type(decoded[u'species']))
print(decoded[u'species'])
# Out:
# [{u'division': u'EnsemblVertebrates', u'strain_collection': u'mouse', u'assembly': u'NZO_HlLtJ_v1', u'name': u'mus_musculus_nzohlltj', u'common_name': u'house mouse', u'accession': u'GCA_001624745.1', u'release': 96, u'strain': u'NZO/HlLtJ', u'groups': [u'funcgen', u'core'], u'taxon_id': u'10090', u'display_name': u'Mouse NZO/HlLtJ', u'aliases': []}, {u'division': u'EnsemblVertebrates', u'strain_collection': None, u'assembly': u'aptOwe1', u'name': u'apteryx_owenii', u'display_name': u'Little spotted kiwi', u'common_name': u'little spotted kiwi', u'accession': u'GCA_003342965.1', u'strain': None, u'groups': [u'rnaseq', u'core'], u'taxon_id': u'8824', u'release': 96, u'aliases': []}, {u'division': u'EnsemblVertebrates', u'strain_collection': None, u'display_name': u'Painted turtle', u'name': u'chrysemys_picta_bellii', u'strain': None, u'common_name': u'Western painted turtle', u'accession': u'GCA_000241765.2', u'release': 96, u'groups': [u'rnaseq', u'otherfeatures', u'core'], u'taxon_id': u'8478', u'assembly': u'Chrysemys_picta_bellii-3.0.3', u'aliases': [u'western painted turtle', u'painted turtle']}, {u'division': u'EnsemblVertebrates', u'strain_collection': u'mouse', u'assembly': u'GRCm38', u'name': u'mus_musculus', u'common_name': u'house mouse', u'accession': u'GCA_000001635.8', u'taxon_id': u'10090', u'strain': u'reference (CL57BL6)', u'groups': [u'variation', u'cdna', u'rnaseq', u'funcgen', u'core', u'otherfeatures'], u'release': 96, u'display_name': u'Mouse', u'aliases': [u'musmus', u'm_musculus', u'house mouse', u'mmus', u'10090', u'mus musculus', u'mmusculus', u'mouse', u'ensmm', u'mus']}, {u'division': u'EnsemblVertebrates', u'strain_collection': None, u'assembly': u'ASM275486v1', u'name': u'callithrix_jacchus', u'common_name': u'white-tufted-ear marmoset', u'accession': u'GCA_002754865.1', u'taxon_id': u'9483', u'strain': None, u'groups': [u'rnaseq', u'core', u'funcgen'], u'release': 96, u'display_name': u'Marmoset', u'aliases': [u'9483', u'cjacchus321', u'cjac', u'marmoset', u'caljac', u'cj321', u'callithrix jacchus', u'cjacchus', u'white-tufted-ear marmoset']}, {u'division': u'EnsemblVertebrates', u'strain_collection': None, u'display_name': u'Spotted gar', u'name': u'lepisosteus_oculatus', u'strain': None, u'accession': u'GCA_000242695.1', u'common_name': u'Spotted gar', u'groups': [u'rnaseq', u'otherfeatures', u'core'], u'taxon_id': u'7918', u'assembly': u'LepOcu1', u'aliases': [u'7918', u'loculatus', u'lepocu', u'locu', u'spotted gar', u'lepisosteus oculatus'], u'release': 96}, {u'division': u'EnsemblVertebrates', u'strain_collection': None, u'assembly': u'DEVIL7.0', u'name': u'sarcophilus_harrisii', u'common_name': u'Tasmanian devil', u'accession': u'GCA_000189315.1', u'taxon_id': u'9305', u'strain': None, u'groups': [u'core', u'otherfeatures'], u'release': 96, u'display_name': u'Tasmanian devil', u'aliases': [u'tasmanian_devil', u'devil', u'sarcophilus harrisii', u'9305', u'tdevil', u'sharrisii', u'shar', u'sarhar', u'tasmanian devil']}, {u'division': u'EnsemblVertebrates', u'strain_collection': None, u'assembly': u'Fundulus_heteroclitus-3.0.2', u'name': u'fundulus_heteroclitus', u'common_name': u'mummichog', u'accession': u'GCA_000826765.1', u'taxon_id': u'8078', u'strain': None, u'groups': [u'rnaseq', u'core', u'otherfeatures', u'funcgen'], u'release': 96, u'display_name': u'Mummichog', u'aliases': []}, {u'division': u'EnsemblVertebrates', u'strain_collection': None, u'display_name': u'Ocean sunfish', u'name': u'mola_mola', u'strain': None, u'common_name': u'ocean sunfish', u'accession': u'GCA_001698575.1', u'release': 96, u'groups': [u'core'], u'taxon_id': u'94237', u'assembly': u'ASM169857v1', u'aliases': []}, {u'division': u'EnsemblVertebrates', u'strain_collection': None, u'display_name': u'Ryukyu mouse', u'name': u'mus_caroli', u'strain': u'CAROLI_EIJ', u'accession': u'GCA_900094665.2', u'common_name': u'Ryukyu mouse', u'groups': [u'core'], u'taxon_id': u'10089', u'assembly': u'CAROLI_EIJ_v1.1', u'alias ...

# %% [markdown]
# ### list of res.tensembl.org species:
# https://rest.ensembl.org/documentation/info/species

# %% [markdown]
# # To do
#
# - Write the Readme in step-by-step procedure on how to run script on Rothhpc4. From pull request to setting up virtual environment to options listed clearly. List the header of the GAPIT csv output so users can know how to prepare their gwas results. Mention all functions of the script and what it does.
#
#
# - Make sure you get a list of Ensembl species IDs.
#
#
#  - Map the ensembl species ID to Knetminer ...Knet.
#
#
# - Make the keywords be inputs from a text file. i.e. only 2 inputs in future, a csv from gapit and an optional user defined text file.
#
# - Make -p parameter optional and add default of p = 6.
#
#
# - Avoid the need to create "Formated_results.txt," read directly from csv to the next step.
#
#
# - Remove genetable.txt and genome.json outputs.
#
#
# - Merge the information in knet summary and summary_gene_discovereted together.
