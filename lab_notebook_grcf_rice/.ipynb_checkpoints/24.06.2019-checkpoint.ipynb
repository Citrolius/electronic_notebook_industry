# %%
import pandas as pd
import numpy as np
import requests
import sys

# %%
glist="T:/colin/BRice/V3/genepage-insight/example_list.txt"
klist="T:/colin/BRice/V3/genepage-insight/mock_keyword_list.txt"
olist="T:/colin/BRice/V3/genepage-insight/example_list/example_list.txt"

# %%
def append_summary():
    with open(klist, "r") as fk:
        pheno=[]
        for line in fk:
            pheno.append(line.rstrip())
        #print(pheno)
        summary=pd.read_csv(glist, sep="\t", header=None)
        genes=list(summary[0])
        #return summary
        

        #creating knetminer genepage urls.
        network_view=[]
        keyw2 = "+OR+".join("({})".format(i.replace(" ", "+AND+")) for i in pheno)
        #print(keyw2)
        #define species
        species="wheatknet"
        for i in genes:
            link="http://knetminer.rothamsted.ac.uk/{}/genepage?list={}&keyword={}".format(species, i, keyw2)
            r=requests.get(link)
            network_view.append(r.url)

        #obtaining knetscores for genes
        keyw1 = "%20OR%20".join("({})".format(i.replace(" ", "+AND+")) for i in pheno)
        genestr=(",").join(genes)
        link="http://knetminer.rothamsted.ac.uk/{}/genome?".format(species)
        parameters={"keyword":keyw1, "list":genestr}
        r=requests.get(link, params=parameters)

        #check if requests is successful
        if not r.ok:
                r.raise_for_status()
                sys.exit()
        
        #extract unicode string of geneTable decoded from json
        decoded=r.json()[u'geneTable'].split("\t")
        #remove space or newline at the end
        decoded=(decoded)[:-1]
        
        colnum=9
        #tabulate genetable into 9 columns.
        genetable=np.array(decoded).reshape(len(decoded)//colnum, colnum)
        genetable=pd.DataFrame(genetable[1:,:], columns=genetable[0,:])
                
        knetgenes=list(genetable[u'ACCESSION'])
        knetscores=list(genetable[u'SCORE'])
        knetchro=list(genetable[u'CHRO'])
        knetstart=list(genetable[u'START'])

        #map genes to snps via a dictionary.
        knetdict=dict(zip(knetgenes, knetscores))
        ordered_score=[]
        for i in summary[0]:
            #convert gene id to upper case to avoid sensitivity issues.
            i=i.upper()
            ordered_score.append(knetdict[u'{}'.format(i)])
        summary[u'knetscore'] = ordered_score
        summary[u'network_view']=network_view
        summary.to_csv(olist, sep="\t")
      
        return summary

# %%
append_summary()
# Out:
#                     0 knetscore  \
# 0  TRAESCS1A02G173400    306.22
# 1  TRAESCS4B02G293600     13.10
# 2  TRAESCS6A02G024400      0.00
# 3  TRAESCS6A02G222000    104.23
# 4  TRAESCS5A02G030800    227.47
# 5  TRAESCS4D02G275500     40.21
# 6  TRAESCS7D02G538400     76.91
# 7  TRAESCS7A02G107400     88.59
# 8  TRAESCS3A02G231900      0.00
# 9  TRAESCS3B02G302100     35.66
#
#                                         network_view
# 0  https://knetminer.rothamsted.ac.uk/wheatknet/g...
# 1  https://knetminer.rothamsted.ac.uk/wheatknet/g...
# 2  https://knetminer.rothamsted.ac.uk/wheatknet/g...
# 3  https://knetminer.rothamsted.ac.uk/wheatknet/g...
# 4  https://knetminer.rothamsted.ac.uk/wheatknet/g...
# 5  https://knetminer.rothamsted.ac.uk/wheatknet/g...
# 6  https://knetminer.rothamsted.ac.uk/wheatknet/g...
# 7  https://knetminer.rothamsted.ac.uk/wheatknet/g...
# 8  https://knetminer.rothamsted.ac.uk/wheatknet/g...
# 9  https://knetminer.rothamsted.ac.uk/wheatknet/g...

# %%
def snippet():
    with open(klist, "r") as fk:
        pheno=[]
        for line in fk:
            pheno.append(line.rstrip())
        #print(pheno)
        summary=pd.read_csv(glist, sep="\t", header=None)
        summary.rename (
        columns={
            0:"GENE"
        }, inplace=True
        )
        genes=list(summary["GENE"])
        
        #creating knetminer genepage urls.
        network_view=[]
        keyw2 = "+OR+".join("({})".format(i.replace(" ", "+AND+")) for i in pheno)
        #print(keyw2)
        #define species
        species="wheatknet"
        for i in genes:
            link="http://knetminer.rothamsted.ac.uk/{}/genepage?list={}&keyword={}".format(species, i, keyw2)
            r=requests.get(link)
            network_view.append(r.url)

        #obtaining knetscores for genes
        keyw1 = "%20OR%20".join("({})".format(i.replace(" ", "+AND+")) for i in pheno)
        genestr=(",").join(genes)
        link="http://knetminer.rothamsted.ac.uk/{}/genome?".format(species)
        parameters={"keyword":keyw1, "list":genestr}
        r=requests.get(link, params=parameters)
        url = "http://knetminer.rothamsted.ac.uk/riceknet/genome?keyword={}&list={}".format(keyw1, genestr)
        return url

        #check if requests is successful
        if not r.ok:
                r.raise_for_status()
                sys.exit()
        
        #extract unicode string of geneTable decoded from json
        decoded=r.json()[u'geneTable'].split("\t")
        #remove space or newline at the end
        decoded=(decoded)[:-1]
        
        colnum=9
        #tabulate genetable into 9 columns.
        genetable=np.array(decoded).reshape(len(decoded)//colnum, colnum)
        genetable=pd.DataFrame(genetable[1:,:], columns=genetable[0,:])
        return genetable.shape
                
        knetgenes=list(genetable[u'ACCESSION'])
        knetscores=list(genetable[u'SCORE'])
        knetchro=list(genetable[u'CHRO'])
        knetstart=list(genetable[u'START'])
        #map genes to snps via a dictionary.
        knetdict=dict(zip(knetgenes, knetscores))
        print knetdict
        ordered_score=[]
        for i in genes:
            #convert gene id to upper case to avoid sensitivity issues.
            i=i.upper()
            ordered_score.append(knetdict[u'{}'.format(i)])
        summary[u'knetscore'] = ordered_score
        summary[u'network_view']=network_view
        summary.to_csv(olist, sep="\t", index=False)
        
        summary

# %%
snippet()
# Out:
# u'{"geneTable":"ONDEX-ID\\tACCESSION\\tGENE NAME\\tCHRO\\tSTART\\tTAXID\\tSCORE\\tUSER\\tQTL\\tEVIDENCE\\n119346\\tTRAESCS1A02G173400\\tMSBP1\\t1A\\t309401615\\t4565\\t306.22\\tyes\\t\\tPhenotype__15__NINE-DAY-OLD WILD-TYPE SEEDLI...//\\"ROUND LEAVES, SHORT PETIOLES...//\\"REDUCED ABA SENSITIVITY, RES...//\\"MEDIUM SIZE ROSETTES, LEAVES...//\\"LI+ HYPERSENSITIVE. UNDER LO...//\\"THE PTR5-1 MUTANT GROWS NORM...//\\"DELAYED GROWTH, DARKER LEAF ...//\\"THE PTR1-2 PTR5-2 DOUBLE MUT...//\\"THE PTR5-2 MUTANT GROWS NORM...//PLANTS HAVE WEAK BRI1 PHENOTY...//\\"THE PTR1-1 MUTANT GROWS NORM...//\\"WEAK ALLELE; SLIGHTLY ALTERE...//\\"MUTANT EXHIBITED REDUCED LEA...//\\"ROUND LEAVES, SHORT PETIOLES...//\\"THE PTR1-2 MUTANT GROWS NORM...||MolFunc__2__High-affinity Oligopeptide Tr...//Oligopeptide Transmembrane Tr...||Gene__2__CNGC5//ATL79||BioProc__5__Seed Maturation//Pollen Germination//Very Long-chain Fatty Acid Bi...//Response To Karrikin//Oligopeptide Transport||Publication__66__PMID:27891614//PMID:28815300//PMID:27095837//PMID:27598621//PMID:26969722//PMID:25602612//PMID:25988582//PMID:27251392//PMID:25049362//PMID:24556575//PMID:24784759//PMID:24823379//PMID:24924143//PMID:24084651//PMID:22788984//PMID:23345415//PMID:23448237//PMID:23418598//PMID:23602109//PMID:23199031||Trait__6__pedicel length//root length//root to shoot ratio//Hypocotyl length//stem length//leaf length\\n83346\\tTRAESCS5A02G030800\\tE1-BETA-2\\t5A\\t28103856\\t4565\\t227.47\\tyes\\t\\tPhenotype__5__DOUBLE MUTANT SEEDLINGS ARE I...//INDUCTION OF GERMINATION BY T...//THE POOR INDUCTION OF GERMINA...//\\"WEAK ALLELE; MEDIUM HYPOCOTY...//\\"DOUBLE MUTANT; SLIGHTLY LONG...||BioProc__4__Response To Far Red Light//Regulation Of Photoperiodism,...//Red Light Signaling Pathway//Regulation Of Seed Germination||CelComp__1__Nuclear Speck||PlantOntologyTerm__5__mature plant embryo stage//IL.03 full inflorescence leng...//seed germination stage//plant embryo coleoptilar stage//seed imbibition stage||Publication__58__PMID:29807609//PMID:28444370//PMID:27820825//PMID:27506149//PMID:26839287//PMID:25775589//PMID:23964902//PMID:24246712//PMID:24911206//PMID:25221561//PMID:24471455//PMID:23456246//PMID:23144185//PMID:23292879//PMID:23772959//PMID:24179122//PMID:22516192//PMID:22732244//PMID:22483719//PMID:22849408||Trait__3__germination rate//Hypocotyl length//petiole length\\n74261\\tTRAESCS6A02G222000\\tPSKR1\\t6A\\t414864874\\t4565\\t104.23\\tyes\\t\\tPhenotype__3__PLANTS HAVE WEAK BRI1 PHENOTY...//\\"MUTANT EXHIBITED REDUCED LEA...//MUTANT LEAVES DISPLAY PREMATU...||PlantOntologyTerm__5__mature plant embryo stage//seed germination stage//plant embryo coleoptilar stage//seed imbibition stage//IL.03 full inflorescence leng...||Publication__18__PMID:28815300//PMID:28407076//PMID:27251392//PMID:24924143//PMID:24556575//PMID:23024212//PMID:22353039//PMID:21504901//PMID:21698171//PMID:20733066//PMID:18502977//PMID:17905839//PMID:18775970//PMID:17194768//PMID:16920880//PMID:11152613//PMID:10415096//PMID:8946951||Trait__4__Hypocotyl length//root length//leaf length//lateral root length\\n119246\\tTRAESCS4B02G293600\\tPAA2\\t4B\\t579391172\\t4565\\t13.10\\tyes\\t\\tPlantOntologyTerm__5__mature plant embryo stage//plant embryo coleoptilar stage//seed imbibition stage//IL.03 full inflorescence leng...//seed germination stage\\n62500\\tTRAESCS6A02G024400\\tTRAESCS6A02G024400\\t6A\\t12131874\\t4565\\t0.00\\tyes\\t\\t\\n","evidenceTable":"TYPE\\tNAME\\tSCORE\\tP-VALUE\\tGENES\\tUSER GENES\\tQTLS\\tONDEXID\\nBioProc\\tResponse To Far Red Light\\t1.67\\t0.09378\\t2209\\tTRAESCS5A02G030800\\t0\\t491925\\nPhenotype\\tMUTANT LEAVES DISPLAY PREMATU...\\t3.15\\t0.01399\\t307\\tTRAESCS6A02G222000\\t0\\t443711\\nTrait\\tgermination rate\\t10.65\\t0.11461\\t2756\\tTRAESCS5A02G030800\\t0\\t722332\\nPhenotype\\t\\"WEAK ALLELE; MEDIUM HYPOCOTY...\\t3.42\\t0.00888\\t194\\tTRAESCS5A02G030800\\t0\\t444273\\nPhenotype\\t\\"DOUBLE MUTANT; SLIGHTLY LONG...\\t3.42\\t0.00920\\t201\\tTRAESCS5A02G030800\\t0\\t4442 ...

# %%
"TRAESCS1A02G173400" == u'TRAESCS1A02G173400'
# Out:
# True
